# %%
## Standard libraries
import os
import pandas as pd
from tabulate import tabulate

## Seeds
import random
import numpy as np

## PyTorch
import torch
import torch.utils.data as data

# Custom libraries
from networks.SimpleMLPs import MLPsumV2
from dataloader_pickles import DataloaderEvalV5
import utils
from pytorch_metric_learning import losses, distances
from tqdm import tqdm

## UMAP libraries
import matplotlib.pyplot as plt
import umap.plot
import matplotlib as mpl
import copy
import plotly.express as px

from sklearn.metrics.pairwise import cosine_similarity
import seaborn as sns

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

NUM_WORKERS = 0
device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")

# Set random seed for reproducibility
manualSeed = 42
random.seed(manualSeed)
torch.manual_seed(manualSeed)
np.random.seed(manualSeed)

# %%
#%%
# Load model
save_name_extension = 'general_ckpt_simpleMLP_V1'
model_name = save_name_extension
print('Loading:', model_name)

input_dim = 1324
kFilters = 1/2
latent_dim = 2048
output_dim = 2048
model = MLPsumV2(input_dim=input_dim, latent_dim=latent_dim, output_dim=output_dim,
                 k=kFilters, dropout=0, cell_layers=1,
                 proj_layers=2, reduction='sum')
if torch.cuda.is_available():
    model.cuda()

path = r'/Users/rdijk/PycharmProjects/featureAggregation/wandb/run-20220505_221947-1m1zas58/files'

models = os.listdir(path)
fullpath = os.path.join(path, model_name)
if 'ckpt' in model_name:
    model.load_state_dict(torch.load(fullpath)['model_state_dict'])
else:
    model.load_state_dict(torch.load(fullpath))
model.eval()

#%% Select specific plate and compound
plates = ['BR00112197binned_FS']
# Out:
# Loading: general_ckpt_simpleMLP_V1

# %%
#%%
# Load all data
rootDir = r'/Users/rdijk/PycharmProjects/featureAggregation/datasets/Stain2'
metadata = pd.read_csv('/Users/rdijk/Documents/Data/RawData/Stain2/JUMP-MOA_compound_platemap_with_metadata.csv', index_col=False)
plateDirs = [x[0] for x in os.walk(rootDir)][1:]

plateDirs = [x for x in plateDirs if any(substr in x for substr in plates)]

platestring = plateDirs[0].split('_')[-2]
print('Calculating results for: ' + platestring)
metadata = utils.addDataPathsToMetadata(rootDir, metadata, plateDirs)

# Filter the data and create numerical labels
df_prep = utils.filterData(metadata, '', encode='pert_iname')
# Add all data to one DF
Total, _ = utils.train_val_split(df_prep, 1.0, sort=False)
Total = Total.sort_values(by='Metadata_labels')

# Select only validation compounds
#valTotal = Total.sort_values(by='Metadata_labels').iloc[288:, :].reset_index(drop=True)

valset = DataloaderEvalV5(Total)
full_loader = data.DataLoader(valset, batch_size=1, shuffle=False, # 96
                         drop_last=False, pin_memory=False, num_workers=NUM_WORKERS)
# Out:
# Calculating results for: BR00112197binned

# %%
# Calculate profiles
MLP_profiles = pd.DataFrame()
with torch.no_grad():
    for idx, (points, labels) in enumerate(tqdm(full_loader)):
        feats, _ = model(points) 
        c1 = pd.concat([pd.DataFrame(feats), pd.Series(labels)], axis=1)
        MLP_profiles = pd.concat([MLP_profiles, c1])
MLP_profiles.columns = [f"f{x}" for x in range(MLP_profiles.shape[1] - 1)] + ['Metadata_labels']
MLP_profiles = MLP_profiles.reset_index(drop=True)
# Out:
# 100%|█████████████████████████████████████████| 384/384 [00:27<00:00, 13.85it/s]

# %%
metadata.sort_values(by='Metadata_labels').reset_index(drop=True).iloc[384-48:].reset_index(drop=True)
# Out:
#    well_position            broad_sample solvent                     InChIKey  \
# 0            H22  BRD-A12994259-001-02-1    DMSO  UVSMNLNDYGZFPF-UHFFFAOYSA-N
# 1            N17  BRD-A12994259-001-02-1    DMSO  UVSMNLNDYGZFPF-UHFFFAOYSA-N
# 2            O03  BRD-A12994259-001-02-1    DMSO  UVSMNLNDYGZFPF-UHFFFAOYSA-N
# 3            K04  BRD-A12994259-001-02-1    DMSO  UVSMNLNDYGZFPF-UHFFFAOYSA-N
# 4            D11  BRD-K44227013-001-08-0    DMSO  PHXJVRSECIGDHY-UHFFFAOYSA-N
# 5            K23  BRD-K44227013-001-08-0    DMSO  PHXJVRSECIGDHY-UHFFFAOYSA-N
# 6            H04  BRD-K44227013-001-08-0    DMSO  PHXJVRSECIGDHY-UHFFFAOYSA-N
# 7            A24  BRD-K44227013-001-08-0    DMSO  PHXJVRSECIGDHY-UHFFFAOYSA-N
# 8            M07  BRD-K73397362-001-06-6    DMSO  FYBHCRQFSFYWPY-UHFFFAOYSA-N
# 9            M08  BRD-K73397362-001-06-6    DMSO  FYBHCRQFSFYWPY-UHFFFAOYSA-N
# 10           N24  BRD-K73397362-001-06-6    DMSO  FYBHCRQFSFYWPY-UHFFFAOYSA-N
# 11           B17  BRD-K73397362-001-06-6    DMSO  FYBHCRQFSFYWPY-UHFFFAOYSA-N
# 12           A12  BRD-K63631219-001-01-6    DMSO  XIXXNJFWPAVKFR-UHFFFAOYSA-N
# 13           N13  BRD-K63631219-001-01-6    DMSO  XIXXNJFWPAVKFR-UHFFFAOYSA-N
# 14           P16  BRD-K63631219-001-01-6    DMSO  XIXXNJFWPAVKFR-UHFFFAOYSA-N
# 15           I11  BRD-K63631219-001-01-6    DMSO  XIXXNJFWPAVKFR-UHFFFAOYSA-N
# 16           B11  BRD-K67772619-001-05-1    DMSO  FFWOKTFYGVYKIR-UHFFFAOYSA-N
# 17           N02  BRD-K67772619-001-05-1    DMSO  FFWOKTFYGVYKIR-UHFFFAOYSA-N
# 18           I22  BRD-K67772619-001-05-1    DMSO  FFWOKTFYGVYKIR-UHFFFAOYSA-N
# 19           C21  BRD-K67772619-001-05-1    DMSO  FFWOKTFYGVYKIR-UHFFFAOYSA-N
# 20           G14  BRD-K61397605-001-07-5    DMSO  OHRURASPPZQGQM-GCCNXGTGSA-N
# 21           H12  BRD-K61397605-001-07-5    DMSO  OHRURASPPZQGQM-GCCNXGTGSA-N
# 22           J03  BRD-K61397605-001-07-5    DMSO  OHRURASPPZQGQM-GCCNXGTGSA-N
# 23           O13  BRD-K61397605-001-07-5    DMSO  OHRURASPPZQGQM-GCCNXGTGSA-N
# 24           H06  BRD-K53972329-001-07-0    DMSO  HFNKQEVNSGCOJV-OAHLLOKOSA-N
# 25           N11  BRD-K53972329-001-07-0    DMSO  HFNKQEVNSGCOJV-OAHLLOKOSA-N
# 26           I15  BRD-K53972329-001-07-0    DMSO  HFNKQEVNSGCOJV-OAHLLOKOSA-N
# 27           O16  BRD-K53972329-001-07-0    DMSO  HFNKQEVNSGCOJV-OAHLLOKOSA-N
# 28           B16  BRD-K57080016-001-01-9    DMSO  CYOHGALHFOKKQC-UHFFFAOYSA-N
# 29           P19  BRD-K57080016-001-01-9    DMSO  CYOHGALHFOKKQC-UHFFFAOYSA-N
# 30           K06  BRD-K57080016-001-01-9    DMSO  CYOHGALHFOKKQC-UHFFFAOYSA-N
# 31           O05  BRD-K57080016-001-01-9    DMSO  CYOHGALHFOKKQC-UHFFFAOYSA-N
# 32           J10  BRD-K84937637-001-11-5    DMSO  QFJCIRLUMZQUOT-HPLJOQBZSA-N
# 33           A23  BRD-K84937637-001-11-5    DMSO  QFJCIRLUMZQUOT-HPLJOQBZSA-N
# 34           E24  BRD-K84937637-001-11-5    DMSO  QFJCIRLUMZQUOT-HPLJOQBZSA-N
# 35           H01  BRD-K84937637-001-11-5    DMSO  QFJCIRLUMZQUOT-HPLJOQBZSA-N
# 36           C02  BRD-K83607951-001-02-2    DMSO  HXMGCTFLLWPVFM-GOSISDBHSA-N
# 37           B20  BRD-K83607951-001-02-2    DMSO  HXMGCTFLLWPVFM-GOSISDBHSA-N
# 38           F17  BRD-K83607951-001-02-2    DMSO  HXMGCTFLLWPVFM-GOSISDBHSA-N
# 39           G01  BRD-K83607951-001-02-2    DMSO  HXMGCTFLLWPVFM-GOSISDBHSA-N
# 40           H20  BRD-K72951360-001-01-4    DMSO  ZOCKGBMQLCSHFP-KQRAQHLDSA-N
# 41           C01  BRD-K72951360-001-01-4    DMSO  ZOCKGBMQLCSHFP-KQRAQHLDSA-N
# 42           D23  BRD-K72951360-001-01-4    DMSO  ZOCKGBMQLCSHFP-KQRAQHLDSA-N
# 43           G02  BRD-K72951360-001-01-4    DMSO  ZOCKGBMQLCSHFP-KQRAQHLDSA-N
# 44           A14  BRD-K12737986-001-01-4    DMSO  JNAHVYVRKWKWKQ-ZDUSSCGKSA-N
# 45           K13  BRD-K12737986-001-01-4    DMSO  JNAHVYVRKWKWKQ-ZDUSSCGKSA-N
# 46           D01  BRD-K12737986-001-01-4    DMSO  JNAHVYVRKWKWKQ-ZDUSSCGKSA-N
# 47           B06  BRD-K12737986-001-01-4    DMSO  JNAHVYVRKWKWKQ-ZDUSSCGKSA-N
#
#        pert_iname  pubchem_cid                                         moa  \
# 0    pomalidomide     134780.0  tumor necrosis factor production inhibitor
# 1    pomalidomide     134780.0  tumor necrosis factor production inhibitor
# 2    pomalidomide     134780.0  tumor necrosis factor production inhibitor
# 3    pomalidomide     134780.0  tumor necrosis factor production inhibitor
# 4       ponatinib   24826799.0                    Bcr-Abl kinase inhibitor
# 5       ponatinib   24826799.0                    Bcr-Abl kinase inhibitor
# 6       ponatinib   24826799.0                    Bcr-Abl kinase inhibitor
# 7       ponatinib   24826799.0                    Bcr-Abl kinase inhibitor
# 8   purmorphamine    5284329.0                 smoothened receptor agonist
# 9   purmorphamine    5284329.0                 smoothened receptor agonist
# 10  purmorphamine    5284329.0                 smoothened receptor agonist
# 11  purmorphamine    5284329.0                 smoothened receptor agonist
# 12      quazinone   57046956.0                 phosphodiesterase inhibitor
# 13      quazinone   57046956.0                 phosphodiesterase inhibitor
# 14      quazinone   57046956.0                 phosphodiesterase inhibitor
# 15      quazinone   57046956.0                 phosphodiesterase inhibitor
# 16  rheochrysidin      10639.0           protein tyrosine kinase inhibitor
# 17  rheochrysidin      10639.0           protein tyrosine kinase inhibitor
# 18  rheochrysidin      10639.0           protein tyrosine kinase inhibitor
# 19  rheochrysidin      10639.0           protein tyrosine kinase inhibitor
# 20     romidepsin    5352062.0                              HDAC inhibitor
# 21     romidepsin    5352062.0                              HDAC inhibitor
# 22     romidepsin    5352062.0                              HDAC inhibitor
# 23     romidepsin    5352062.0                              HDAC inhibitor
# 24    ruxolitinib   25126798.0                               JAK inhibitor
# 25    ruxolitinib   25126798.0                               JAK inhibitor
# 26    ruxolitinib   25126798.0                               JAK inhibitor
# 27    ruxolitinib   25126798.0                               JAK inhibitor
# 28    selumetinib   10127622.0                               MEK inhibitor
# 29    selumetinib   10127622.0                               MEK inhibitor
# 30    selumetinib   10127622.0                               MEK inhibitor
# 31    selumetinib   10127622.0                               MEK inhibitor
# 32      sirolimus    5284616.0                              mTOR inhibitor
# 33      sirolimus    5284616.0                              mTOR inhibitor
# 34      sirolimus    5284616.0                              mTOR inhibitor
# 35      sirolimus    5284616.0                              mTOR inhibitor
# 36    skepinone-l   45279963.0                          p38 MAPK inhibitor
# 37    skepinone-l   45279963.0                          p38 MAPK inhibitor
# 38    skepinone-l   45279963.0                          p38 MAPK inhibitor
# 39    skepinone-l   45279963.0                          p38 MAPK inhibitor
# 40     valrubicin     454216.0                               DNA inhibitor
# 41     valrubicin     454216.0                               DNA inhibitor
# 42     valrubicin     454216.0                               DNA inhibitor
# 43     valrubicin     454216.0                               DNA inhibitor
# 44      veliparib   11842604.0                              PARP inhibitor
# 45      veliparib   11842604.0                              PARP inhibitor
# 46      veliparib   11842604.0                              PARP inhibitor
# 47      veliparib   11842604.0                              PARP inhibitor
#
#                                                smiles pert_type control_type  \
# 0              Nc1cccc2C(=O)N(C3CCC(=O)NC3=O)C(=O)c12       trt          NaN
# 1              Nc1cccc2C(=O)N(C3CCC(=O)NC3=O)C(=O)c12       trt          NaN
# 2              Nc1cccc2C(=O)N(C3CCC(=O)NC3=O)C(=O)c12       trt          NaN
# 3              Nc1cccc2C(=O)N(C3CCC(=O)NC3=O)C(=O)c12       trt          NaN
# 4   CN1CCN(Cc2ccc(NC(=O)c3ccc(C)c(c3)C#Cc3cnc4cccn...       trt          NaN
# 5   CN1CCN(Cc2ccc(NC(=O)c3ccc(C)c(c3)C#Cc3cnc4cccn...       trt          NaN
# 6   CN1CCN(Cc2ccc(NC(=O)c3ccc(C)c(c3)C#Cc3cnc4cccn...       trt          NaN
# 7   CN1CCN(Cc2ccc(NC(=O)c3ccc(C)c(c3)C#Cc3cnc4cccn...       trt          NaN
# 8   C1CCC(CC1)n1cnc2c(Nc3ccc(cc3)N3CCOCC3)nc(Oc3cc...       trt          NaN
# 9   C1CCC(CC1)n1cnc2c(Nc3ccc(cc3)N3CCOCC3)nc(Oc3cc...       trt          NaN
# 10  C1CCC(CC1)n1cnc2c(Nc3ccc(cc3)N3CCOCC3)nc(Oc3cc...       trt          NaN
# 11  C1CCC(CC1)n1cnc2c(Nc3ccc(cc3)N3CCOCC3)nc(Oc3cc...       trt          NaN
# 12                        Cc1c(O)nc2Nc3cccc(Cl)c3Cn12       trt          NaN
# 13                        Cc1c(O)nc2Nc3cccc(Cl)c3Cn12       trt          NaN
# 14                        Cc1c(O)nc2Nc3cccc(Cl)c3Cn12       trt          NaN
# 15                        Cc1c(O)nc2Nc3cccc(Cl)c3Cn12       trt          NaN
# 16            COc1cc(O)c2C(=O)c3c(O)cc(C)cc3C(=O)c2c1       trt          NaN
# 17            COc1cc(O)c2C(=O)c3c(O)cc(C)cc3C(=O)c2c1       trt          NaN
# 18            COc1cc(O)c2C(=O)c3c(O)cc(C)cc3C(=O)c2c1       trt          NaN
# 19            COc1cc(O)c2C(=O)c3c(O)cc(C)cc3C(=O)c2c1       trt          NaN
# 20  C\C=C1/NC(=O)[C@H]2CSSCC\C=C\[C@H](CC(=O)N[C@H...       trt          NaN
# 21  C\C=C1/NC(=O)[C@H]2CSSCC\C=C\[C@H](CC(=O)N[C@H...       trt          NaN
# 22  C\C=C1/NC(=O)[C@H]2CSSCC\C=C\[C@H](CC(=O)N[C@H...       trt          NaN
# 23  C\C=C1/NC(=O)[C@H]2CSSCC\C=C\[C@H](CC(=O)N[C@H...       trt          NaN
# 24       N#CC[C@H](C1CCCC1)n1cc(cn1)-c1ncnc2[nH]ccc12       trt          NaN
# 25       N#CC[C@H](C1CCCC1)n1cc(cn1)-c1ncnc2[nH]ccc12       trt          NaN
# 26       N#CC[C@H](C1CCCC1)n1cc(cn1)-c1ncnc2[nH]ccc12       trt          NaN
# 27       N#CC[C@H](C1CCCC1)n1cc(cn1)-c1ncnc2[nH]ccc12       trt          NaN
# 28     Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(cc12)C(=O)NOCCO       trt          NaN
# 29     Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(cc12)C(=O)NOCCO       trt          NaN
# 30     Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(cc12)C(=O)NOCCO       trt          NaN
# 31     Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(cc12)C(=O)NOCCO       trt          NaN
# 32  CO[C@@H]1C[C@H](C[C@@H](C)[C@@H]2CC(=O)[C@H](C...       trt          NaN
# 33  CO[C@@H]1C[C@H](C[C@@H](C)[C@@H]2CC(=O)[C@H](C...       trt          NaN
# 34  CO[C@@H]1C[C@H](C[C@@H](C)[C@@H]2CC(=O)[C@H](C...       trt          NaN
# 35  CO[C@@H]1C[C@H](C[C@@H](C)[C@@H]2CC(=O)[C@H](C...       trt          NaN
# 36  OC[C@@H](O)COc1ccc2CCc3cc(Nc4ccc(F)cc4F)ccc3C(...       trt          NaN
# 37  OC[C@@H](O)COc1ccc2CCc3cc(Nc4ccc(F)cc4F)ccc3C(...       trt          NaN
# 38  OC[C@@H](O)COc1ccc2CCc3cc(Nc4ccc(F)cc4F)ccc3C(...       trt          NaN
# 39  OC[C@@H](O)COc1ccc2CCc3cc(Nc4ccc(F)cc4F)ccc3C(...       trt          NaN
# 40  CCCCC(=O)OCC(=O)[C@@]1(O)C[C@H](O[C@H]2C[C@H](...       trt          NaN
# 41  CCCCC(=O)OCC(=O)[C@@]1(O)C[C@H](O[C@H]2C[C@H](...       trt          NaN
# 42  CCCCC(=O)OCC(=O)[C@@]1(O)C[C@H](O[C@H]2C[C@H](...       trt          NaN
# 43  CCCCC(=O)OCC(=O)[C@@]1(O)C[C@H](O[C@H]2C[C@H](...       trt          NaN
# 44              C[C@]1(CCCN1)c1nc2c(cccc2[nH]1)C(N)=O       trt          NaN
# 45              C[C@]1(CCCN1)c1nc2c(cccc2[nH]1)C(N)=O       trt          NaN
# 46              C[C@]1(CCCN1)c1nc2c(cccc2[nH]1)C(N)=O       trt          NaN
# 47              C[C@]1(CCCN1)c1nc2c(cccc2[nH]1)C(N)=O       trt          NaN
#
#                                                plate1  Metadata_labels
# 0   /Users/rdijk/PycharmProjects/featureAggregatio...               79
# 1   /Users/rdijk/PycharmProjects/featureAggregatio...               79
# 2   /Users/rdijk/PycharmProjects/featureAggregatio...               79
# 3   /Users/rdijk/PycharmProjects/featureAggregatio...               79
# 4   /Users/rdijk/PycharmProjects/featureAggregatio...               80
# 5   /Users/rdijk/PycharmProjects/featureAggregatio...               80
# 6   /Users/rdijk/PycharmProjects/featureAggregatio...               80
# 7   /Users/rdijk/PycharmProjects/featureAggregatio...               80
# 8   /Users/rdijk/PycharmProjects/featureAggregatio...               81
# 9   /Users/rdijk/PycharmProjects/featureAggregatio...               81
# 10  /Users/rdijk/PycharmProjects/featureAggregatio...               81
# 11  /Users/rdijk/PycharmProjects/featureAggregatio...               81
# 12  /Users/rdijk/PycharmProjects/featureAggregatio...               82
# 13  /Users/rdijk/PycharmProjects/featureAggregatio...               82
# 14  /Users/rdijk/PycharmProjects/featureAggregatio...               82
# 15  /Users/rdijk/PycharmProjects/featureAggregatio...               82
# 16  /Users/rdijk/PycharmProjects/featureAggregatio...               83
# 17  /Users/rdijk/PycharmProjects/featureAggregatio...               83
# 18  /Users/rdijk/PycharmProjects/featureAggregatio...               83
# 19  /Users/rdijk/PycharmProjects/featureAggregatio...               83
# 20  /Users/rdijk/PycharmProjects/featureAggregatio...               84
# 21  /Users/rdijk/PycharmProjects/featureAggregatio...               84
# 22  /Users/rdijk/PycharmProjects/featureAggregatio...               84
# 23  /Users/rdijk/PycharmProjects/featureAggregatio...               84
# 24  /Users/rdijk/PycharmProjects/featureAggregatio...               85
# 25  /Users/rdijk/PycharmProjects/featureAggregatio...               85
# 26  /Users/rdijk/PycharmProjects/featureAggregatio...               85
# 27  /Users/rdijk/PycharmProjects/featureAggregatio...               85
# 28  /Users/rdijk/PycharmProjects/featureAggregatio...               86
# 29  /Users/rdijk/PycharmProjects/featureAggregatio...               86
# 30  /Users/rdijk/PycharmProjects/featureAggregatio...               86
# 31  /Users/rdijk/PycharmProjects/featureAggregatio...               86
# 32  /Users/rdijk/PycharmProjects/featureAggregatio...               87
# 33  /Users/rdijk/PycharmProjects/featureAggregatio...               87
# 34  /Users/rdijk/PycharmProjects/featureAggregatio...               87
# 35  /Users/rdijk/PycharmProjects/featureAggregatio...               87
# 36  /Users/rdijk/PycharmProjects/featureAggregatio...               88
# 37  /Users/rdijk/PycharmProjects/featureAggregatio...               88
# 38  /Users/rdijk/PycharmProjects/featureAggregatio...               88
# 39  /Users/rdijk/PycharmProjects/featureAggregatio...               88
# 40  /Users/rdijk/PycharmProjects/featureAggregatio...               89
# 41  /Users/rdijk/PycharmProjects/featureAggregatio...               89
# 42  /Users/rdijk/PycharmProjects/featureAggregatio...               89
# 43  /Users/rdijk/PycharmProjects/featureAggregatio...               89
# 44  /Users/rdijk/PycharmProjects/featureAggregatio...               90
# 45  /Users/rdijk/PycharmProjects/featureAggregatio...               90
# 46  /Users/rdijk/PycharmProjects/featureAggregatio...               90
# 47  /Users/rdijk/PycharmProjects/featureAggregatio...               90

# %%
#%% Choose which wells to calculate saliencies for

point_list = [8, 9, 10, 11]

WELLS = list(metadata.sort_values(by='Metadata_labels').reset_index(drop=True).iloc[384-48:].reset_index(drop=True).loc[point_list, 'well_position'])
PERTURBATIONS = list(metadata.sort_values(by='Metadata_labels').reset_index(drop=True).iloc[384-48:].reset_index(drop=True).loc[point_list, 'pert_iname'])
print(WELLS, PERTURBATIONS)
# Out:
# ['M07', 'M08', 'N24', 'B17'] ['purmorphamine', 'purmorphamine', 'purmorphamine', 'purmorphamine']

# %%
metadata_indices_used = []
for i in range(len(WELLS)):
    a = metadata.sort_values(by='Metadata_labels').reset_index(drop=True)[metadata['well_position'] == WELLS[i]].index
    metadata_indices_used.append(a)

# %%
mask_list = []
dataloader_list = []
for well in WELLS:
    # Load single well data
    mask = df_prep.well_position == well
    df_prep_masked = df_prep.loc[mask]
    # Add all data to one DF
    singleWell, _ = utils.train_val_split(df_prep_masked, 1.0, sort=False)

    smallset = DataloaderEvalV5(singleWell)
    dataloader = data.DataLoader(smallset, batch_size=1, shuffle=False,
                             drop_last=False, pin_memory=False, num_workers=NUM_WORKERS)
    
    mask_list.append(mask)
    dataloader_list.append(dataloader)

# %%
df_prep_masked.head() # Show last one in for loop
# Out:
#    well_position            broad_sample solvent                     InChIKey  \
# 40           B17  BRD-K73397362-001-06-6    DMSO  FYBHCRQFSFYWPY-UHFFFAOYSA-N
#
#        pert_iname  pubchem_cid                          moa  \
# 40  purmorphamine    5284329.0  smoothened receptor agonist
#
#                                                smiles pert_type control_type  \
# 40  C1CCC(CC1)n1cnc2c(Nc3ccc(cc3)N3CCOCC3)nc(Oc3cc...       trt          NaN
#
#                                                plate1  Metadata_labels
# 40  /Users/rdijk/PycharmProjects/featureAggregatio...               81

# %%
def SNR(a, axis=0, ddof=0):
    a = np.asanyarray(a)
    m = a.mean(axis)
    sd = a.std(axis=axis, ddof=ddof)
    return np.where(sd == 0, 0, m/sd)

# %%
def N(a):
    a = np.asanyarray(a)
    m = a[0, :].mean()
    N = np.sqrt(np.mean((m - a)**2, 1))
    return N

# %% [markdown]
# ## Saliency V0 - Activation layer based slaliency (L1 norm per cell)

# %%
admixing_fractions = [0.05, 0.1, 0.2, 0.4, 1]
for frac in admixing_fractions:

    highpoints = []
    lowpoints = []

    for loader, mask in zip(dataloader_list, mask_list):
        points, clabel = next(iter(loader))

        _, profile = model(points)

        saliency_V0 = torch.sum(abs(profile), dim=2)

        saliency_V0 = np.squeeze(np.array(saliency_V0.detach()))

        cutoff = int(points.shape[1]*frac)
        topidx = sorted(range(len(saliency_V0)), key=lambda i: saliency_V0[i])[-cutoff:]
        botidx = sorted(range(len(saliency_V0)), key=lambda i: saliency_V0[i])[:cutoff]
        highpoints.append(points[0,topidx,:])
        lowpoints.append(points[0,botidx,:])
    
    highpoints = torch.cat(highpoints)
    lowpoints = torch.cat(lowpoints)
    print(highpoints.shape)
    
    ## PERMUTATION TEST
    NPERM = 1000
    npcas = 4
    ncells = highpoints.shape[0]

    noutputs = []
    
    ridxh = np.random.choice(ncells, NPERM)
    highcells_pool = highpoints[ridxh, :].detach()
    ridxl = np.random.choice(ncells, NPERM+1)
    lowcells = lowpoints[ridxl, :].detach()
    for x in range(NPERM+1):
        lowcells = np.delete(lowcells, 0, 0)
        highcells = highcells_pool[:x, :]

        fusedcells = torch.unsqueeze(torch.cat([highcells, lowcells]), 0)

        profile, _ = model(fusedcells)
        profile = profile.detach().numpy()[0,...]
        # Normalize profiles (per row)
        profile = (profile - np.min(profile)) / (np.max(profile) - np.min(profile))
        noutputs.append(profile)

    # Calculate PCAs
    pca = PCA(n_components=npcas, random_state=42)
    pcs = pca.fit_transform(np.stack(noutputs))
    

    fig, ax = plt.subplots(1,1, figsize = (10,10))
    for i in range(npcas):
        ax.plot(np.array(range(NPERM+1))/NPERM, pcs[:,i], label=f'PC{i+1}')
    ax.legend()

    ax.set_xlabel('admixing fraction')
    ax.set_ylabel('PC value')
    ax.set_title(f'saliency threshold: {frac}')
    plt.show()

#     fig, ax = plt.subplots(1,2, figsize = (15,10))
#     for i in range(npcas):
#         ax[0].plot(np.array(range(NPERM+1))/NPERM, pcs[:,i], label=f'PC{i+1}')
#     ax[0].legend()

#     ax[0].set_xlabel('admixing fraction')
#     ax[0].set_ylabel('PC value')
#     ax[0].set_title(f'saliency threshold: {frac}')
    
#     # Calculate signal to noise ratios 
#     snrs = SNR(np.stack(noutputs), 1)
#     ax[1].plot(np.array(range(NPERM+1))/NPERM, snrs)

#     ax[1].set_xlabel('admixing fraction')
#     ax[1].set_ylabel('SNR (-)')
#     ax[1].set_title(f'SNR with saliency threshold: {frac}')
#     plt.show()
# Out:
# torch.Size([604, 1324])
# torch.Size([1210, 1324])
# torch.Size([2422, 1324])
# torch.Size([4846, 1324])
# torch.Size([12120, 1324])

# %% [markdown]
# ## Saliency V1 - Gradient based saliency (L1 norm per cell)

# %%
#%% Saliency_V1 Calculate gradient based saliencies - L1 norm of gradients per cell 
loss_func = losses.SupConLoss(distance=distances.CosineSimilarity())

admixing_fractions = [0.05, 0.1, 0.2, 0.4, 1]
for frac in admixing_fractions:

    highpoints = []
    lowpoints = []

    for loader, mask in zip(dataloader_list, mask_list):
        points, clabel = next(iter(loader))

        MLP_profiles_masked = MLP_profiles[~mask] # remove well profile that we are analysing
        points.requires_grad_()
        profile, _ = model(points)

        L = loss_func(torch.cat([torch.tensor(MLP_profiles_masked.iloc[:, :-1].values), profile]), 
                      torch.cat([torch.tensor(MLP_profiles_masked.iloc[:, -1].values), clabel]))

        features_loss = L.backward()
        saliency_V1 = torch.sum(points.grad.data.abs(), dim=2)
        saliency_V1 = np.squeeze(np.array(saliency_V1))

        cutoff = int(points.shape[1]*frac)
        topidx = sorted(range(len(saliency_V1)), key=lambda i: saliency_V1[i])[-cutoff:]
        botidx = sorted(range(len(saliency_V1)), key=lambda i: saliency_V1[i])[:cutoff]
        highpoints.append(points[0,topidx,:])
        lowpoints.append(points[0,botidx,:])
    
    highpoints = torch.cat(highpoints)
    lowpoints = torch.cat(lowpoints)
    print(highpoints.shape)
    
    ## PERMUTATION TEST
    NPERM = 1000
    npcas = 4
    ncells = highpoints.shape[0]

    noutputs = []
    
    ridxh = np.random.choice(ncells, NPERM)
    highcells_pool = highpoints[ridxh, :].detach()
    ridxl = np.random.choice(ncells, NPERM+1)
    lowcells = lowpoints[ridxl, :].detach()
    for x in range(NPERM+1):
        lowcells = np.delete(lowcells, 0, 0)
        highcells = highcells_pool[:x, :]

        fusedcells = torch.unsqueeze(torch.cat([highcells, lowcells]), 0)

        profile, _ = model(fusedcells)
        profile = profile.detach().numpy()[0,...]
        # Normalize profiles (per row)
        profile = (profile - np.min(profile)) / (np.max(profile) - np.min(profile))
        noutputs.append(profile)

    # Calculate PCAs
    pca = PCA(n_components=npcas, random_state=42)
    pcs = pca.fit_transform(np.stack(noutputs))
    

    fig, ax = plt.subplots(1,1, figsize = (10,10))
    for i in range(npcas):
        ax.plot(np.array(range(NPERM+1))/NPERM, pcs[:,i], label=f'PC{i+1}')
    ax.legend()

    ax.set_xlabel('admixing fraction')
    ax.set_ylabel('PC value')
    ax.set_title(f'saliency threshold: {frac}')
    plt.show()

#     fig, ax = plt.subplots(1,2, figsize = (15,10))
#     for i in range(npcas):
#         ax[0].plot(np.array(range(NPERM+1))/NPERM, pcs[:,i], label=f'PC{i+1}')
#     ax[0].legend()

#     ax[0].set_xlabel('admixing fraction')
#     ax[0].set_ylabel('PC value')
#     ax[0].set_title(f'saliency threshold: {frac}')
    
#     # Calculate signal to noise ratios 
#     snrs = SNR(np.stack(noutputs), 1)
#     ax[1].plot(np.array(range(NPERM+1))/NPERM, snrs)

#     ax[1].set_xlabel('admixing fraction')
#     ax[1].set_ylabel('SNR (-)')
#     ax[1].set_title(f'SNR with saliency threshold: {frac}')
#     plt.show()
# Out:
# torch.Size([604, 1324])
# torch.Size([1210, 1324])
# torch.Size([2422, 1324])
# torch.Size([4846, 1324])
# torch.Size([12120, 1324])

# %% [markdown]
# ## Saliency V0 + Saliency V1

# %%
#%% Saliency_V1 Calculate gradient based saliencies - L1 norm of gradients per cell 
loss_func = losses.SupConLoss(distance=distances.CosineSimilarity())

admixing_fractions = [0.05, 0.1, 0.2, 0.4, 1]
for frac in admixing_fractions:

    highpoints = []
    lowpoints = []

    for loader, mask in zip(dataloader_list, mask_list):
        points, clabel = next(iter(loader))

        MLP_profiles_masked = MLP_profiles[~mask] # remove well profile that we are analysing
        points.requires_grad_()
        profile, features = model(points)
        
        saliency_V0 = torch.sum(abs(features), dim=2)
        saliency_V0 = np.squeeze(np.array(saliency_V0.detach()))
        
        L = loss_func(torch.cat([torch.tensor(MLP_profiles_masked.iloc[:, :-1].values), profile]), 
                      torch.cat([torch.tensor(MLP_profiles_masked.iloc[:, -1].values), clabel]))

        features_loss = L.backward()
        saliency_V1 = torch.sum(points.grad.data.abs(), dim=2)
        saliency_V1 = np.squeeze(np.array(saliency_V1))
        
        saliency_V0 = ( saliency_V0 - np.min(saliency_V0) ) / (np.max(saliency_V0) - np.min(saliency_V0))
        saliency_V1 = ( saliency_V1 - np.min(saliency_V1) ) / (np.max(saliency_V1) - np.min(saliency_V1))
        
        saliency_V0_V1 = saliency_V0 + saliency_V1
        
        cutoff = int(points.shape[1]*frac)
        topidx = sorted(range(len(saliency_V0_V1)), key=lambda i: saliency_V0_V1[i])[-cutoff:]
        botidx = sorted(range(len(saliency_V0_V1)), key=lambda i: saliency_V0_V1[i])[:cutoff]
        highpoints.append(points[0,topidx,:])
        lowpoints.append(points[0,botidx,:])
    
    highpoints = torch.cat(highpoints)
    lowpoints = torch.cat(lowpoints)
    print(highpoints.shape)
    
    ## PERMUTATION TEST
    NPERM = 1000
    npcas = 4
    ncells = highpoints.shape[0]

    noutputs = []
    
    ridxh = np.random.choice(ncells, NPERM)
    highcells_pool = highpoints[ridxh, :].detach()
    ridxl = np.random.choice(ncells, NPERM+1)
    lowcells = lowpoints[ridxl, :].detach()
    for x in range(NPERM+1):
        lowcells = np.delete(lowcells, 0, 0)
        highcells = highcells_pool[:x, :]

        fusedcells = torch.unsqueeze(torch.cat([highcells, lowcells]), 0)

        profile, _ = model(fusedcells)
        profile = profile.detach().numpy()[0,...]
        # Normalize profiles (per row)
        profile = (profile - np.min(profile)) / (np.max(profile) - np.min(profile))
        noutputs.append(profile)

    # Calculate PCAs
    pca = PCA(n_components=npcas, random_state=42)
    pcs = pca.fit_transform(np.stack(noutputs))
    

    fig, ax = plt.subplots(1,1, figsize = (10,10))
    for i in range(npcas):
        ax.plot(np.array(range(NPERM+1))/NPERM, pcs[:,i], label=f'PC{i+1}')
    ax.legend()

    ax.set_xlabel('admixing fraction')
    ax.set_ylabel('PC value')
    ax.set_title(f'saliency threshold: {frac}')
    plt.show()
# Out:
# torch.Size([604, 1324])
# torch.Size([1210, 1324])
# torch.Size([2422, 1324])
# torch.Size([4846, 1324])
# torch.Size([12120, 1324])

# %% [markdown]
# ## Saliency V2

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Calculate distance based saliencies - distance of single cell representations to aggregated representation
admixing_fractions = [0.05, 0.1, 0.2, 0.4, 1]
for frac in admixing_fractions:

    highpoints = []
    lowpoints = []

    for loader in dataloader_list:
        points, clabel = next(iter(loader))

        single_cell_profiles = torch.tensor([])
        final_profile, _ = model(points)

        for idx in tqdm(range(points.shape[1])):
            single_cell = points[:, [idx], :]
            sc_profile, _ = model(single_cell)
            single_cell_profiles = torch.cat([single_cell_profiles, sc_profile])
        single_cell_profiles = single_cell_profiles.detach().numpy()
        final_profile = final_profile.detach().numpy()
        cos = cosine_similarity(single_cell_profiles, final_profile)[:, 0]

        cutoff = int(points.shape[1]*frac)
        topidx = sorted(range(len(cos)), key=lambda i: cos[i])[-cutoff:]
        botidx = sorted(range(len(cos)), key=lambda i: cos[i])[:cutoff]
        highpoints.append(points[0,topidx,:])
        lowpoints.append(points[0,botidx,:])
    
    highpoints = torch.cat(highpoints)
    lowpoints = torch.cat(lowpoints)
    print(highpoints.shape)
    
    ## PERMUTATION TEST
    NPERM = 1000
    npcas = 4
    ncells = highpoints.shape[0]

    noutputs = []
    
    ridxh = np.random.choice(ncells, NPERM)
    highcells_pool = highpoints[ridxh, :].detach()
    ridxl = np.random.choice(ncells, NPERM+1)
    lowcells = lowpoints[ridxl, :].detach()
    for x in range(NPERM+1):
        lowcells = np.delete(lowcells, 0, 0)
        highcells = highcells_pool[:x, :]

        fusedcells = torch.unsqueeze(torch.cat([highcells, lowcells]), 0)

        profile, _ = model(fusedcells)
        profile = profile.detach().numpy()[0,...]
        # Normalize profiles (per row)
        profile = (profile - np.min(profile)) / (np.max(profile) - np.min(profile))
        noutputs.append(profile)
    
    # Calculate PCAs
    pca = PCA(n_components=npcas, random_state=42)
    pcs = pca.fit_transform(np.stack(noutputs))
    

    fig, ax = plt.subplots(1,1, figsize = (10,10))
    for i in range(npcas):
        ax.plot(np.array(range(NPERM+1))/NPERM, pcs[:,i], label=f'PC{i+1}')
    ax.legend()

    ax.set_xlabel('admixing fraction')
    ax.set_ylabel('PC value')
    ax.set_title(f'saliency threshold: {frac}')
    plt.show()

#     fig, ax = plt.subplots(1,2, figsize = (15,10))
#     for i in range(npcas):
#         ax[0].plot(np.array(range(NPERM+1))/NPERM, pcs[:,i], label=f'PC{i+1}')
#     ax[0].legend()

#     ax[0].set_xlabel('admixing fraction')
#     ax[0].set_ylabel('PC value')
#     ax[0].set_title(f'saliency threshold: {frac}')
    
#     # Calculate signal to noise ratios 
# #     snrs = SNR(np.stack(noutputs), 1)
# #     snrs = N(np.stack(noutputs))
# #     ax[1].plot(np.array(range(NPERM+1))/NPERM, snrs)

#     x = np.array(range(NPERM+1))/NPERM
#     params = np.polyfit(x, pcs, 3)
#     fittedPCs = [P[0]*x**3 + P[1]*x**2 + P[2]*x**1 + P[3] for P in params]
#     for i in range(fittedPCs):
#         ax[1].plot(x, fittedPCs[:,i], label=f'PC{i+1}')

#     ax[1].set_xlabel('admixing fraction')
#     ax[1].set_ylabel('SNR (-)')
#     ax[1].set_title(f'SNR with saliency threshold: {frac}')
#     plt.show()
# Out:
# 100%|██████████████████████████████████████| 3171/3171 [00:10<00:00, 290.44it/s]
# 100%|██████████████████████████████████████| 3147/3147 [00:10<00:00, 295.87it/s]
# 100%|██████████████████████████████████████| 2878/2878 [00:09<00:00, 309.89it/s]
# 100%|██████████████████████████████████████| 2924/2924 [00:09<00:00, 300.01it/s]
# torch.Size([604, 1324])
# 100%|██████████████████████████████████████| 3171/3171 [00:11<00:00, 286.62it/s]
# 100%|██████████████████████████████████████| 3147/3147 [00:11<00:00, 272.28it/s]
# 100%|██████████████████████████████████████| 2878/2878 [00:10<00:00, 285.39it/s]
# 100%|██████████████████████████████████████| 2924/2924 [00:10<00:00, 289.77it/s]
# torch.Size([1210, 1324])
# 100%|██████████████████████████████████████| 3171/3171 [00:11<00:00, 279.72it/s]
# 100%|██████████████████████████████████████| 3147/3147 [00:10<00:00, 295.49it/s]
# 100%|██████████████████████████████████████| 2878/2878 [00:09<00:00, 309.65it/s]
# 100%|██████████████████████████████████████| 2924/2924 [00:09<00:00, 298.25it/s]
# torch.Size([2422, 1324])
# 100%|██████████████████████████████████████| 3171/3171 [00:11<00:00, 281.29it/s]
# 100%|██████████████████████████████████████| 3147/3147 [00:10<00:00, 287.84it/s]
# 100%|██████████████████████████████████████| 2878/2878 [00:09<00:00, 307.19it/s]
# 100%|██████████████████████████████████████| 2924/2924 [00:09<00:00, 309.63it/s]
# torch.Size([4846, 1324])
# 100%|██████████████████████████████████████| 3171/3171 [00:11<00:00, 287.95it/s]
# 100%|██████████████████████████████████████| 3147/3147 [00:10<00:00, 289.34it/s]
# 100%|██████████████████████████████████████| 2878/2878 [00:09<00:00, 310.85it/s]
# 100%|██████████████████████████████████████| 2924/2924 [00:09<00:00, 293.28it/s]
# torch.Size([12120, 1324])

# %%
    fig, ax = plt.subplots(1,2, figsize = (15,10))
    for i in range(npcas):
        ax[0].plot(np.array(range(NPERM+1))/NPERM, pcs[:,i], label=f'PC{i+1}')
    ax[0].legend()

    ax[0].set_xlabel('admixing fraction')
    ax[0].set_ylabel('PC value')
    ax[0].set_title(f'saliency threshold: {frac}')
    
    # Calculate signal to noise ratios 
#     snrs = SNR(np.stack(noutputs), 1)
#     snrs = N(np.stack(noutputs))
#     ax[1].plot(np.array(range(NPERM+1))/NPERM, snrs)

    x = np.array(range(NPERM+1))/NPERM
    power = 15
    params = np.polyfit(x, pcs[:, 0], power)
    fittedPC1 = 0
    for P in range(len(params)):
        fittedPC1 += params[P]*x**(power-P)
    diffFit = abs(fittedPC1 - pcs[:, 0])
#    ax[1].plot(x, fittedPC1, label=f'fit PC1')
    ax[1].plot(x, diffFit, label=f'diff PC1')
    ax[1].legend()

    ax[1].set_xlabel('admixing fraction')
    ax[1].set_ylabel('Noise (-)')
    ax[1].set_title(f'Noise with saliency threshold: {frac}')
    plt.show()

# %% [markdown]
# ## Saliency V3

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Calculate distance based saliencies - distance of single cell representations to aggregated representation
admixing_fractions = [0.05, 0.1, 0.2, 0.4, 1]
for frac in admixing_fractions:

    highpoints = []
    lowpoints = []
    
    # Calculate saliency
    for loader, mask in zip(dataloader_list, mask_list):
        points, clabel = next(iter(loader))

        # Leave one cell out
        loco_losses = []
        MLP_profiles_masked = MLP_profiles[~mask] # remove well profile that we are analysing
        for idx in tqdm(range(points.shape[1])):
            masked_points = points[:, torch.arange(points.size(1))!=idx, :]
            masked_profile, _ = model(masked_points)

            L = loss_func(torch.cat([torch.tensor(MLP_profiles_masked.iloc[:, :-1].values), masked_profile]), 
                          torch.cat([torch.tensor(MLP_profiles_masked.iloc[:, -1].values), clabel]))
            loco_losses.append(L.item())
   
        loco_losses_array = np.array(loco_losses)
        # Calculate saliency for most noisy cells, that, when removed, decrease the loss the most.
        # Also normalize the saliency values
        saliency_min = np.min(loco_losses_array) / loco_losses_array
        # lowest loss corresponds to noisiest cell, thus invert for most salient cell
        saliency_cells_V3 = abs(1-saliency_min)
    
        cutoff = int(points.shape[1]*frac)
        topidx = sorted(range(len(saliency_cells_V3)), key=lambda i: saliency_cells_V3[i])[-cutoff:]
        botidx = sorted(range(len(saliency_cells_V3)), key=lambda i: saliency_cells_V3[i])[:cutoff]
        highpoints.append(points[0,topidx,:])
        lowpoints.append(points[0,botidx,:])
    
    highpoints = torch.cat(highpoints)
    lowpoints = torch.cat(lowpoints)
    print(highpoints.shape)
    
    
    ## PERMUTATION TEST
    NPERM = 1000
    npcas = 4
    ncells = highpoints.shape[0]

    noutputs = [] 
    ## OLD VERSION WHICH SAMPLES RANDOM CELLS EACH FRACTION
    for x in range(NPERM+1):
        ridxh = np.random.choice(ncells, x)
        highcells = highpoints[ridxh, :]
        ridxl = np.random.choice(ncells, NPERM-x)
        lowcells = lowpoints[ridxl, :]

        fusedcells = torch.unsqueeze(torch.cat([highcells, lowcells]), 0)

        profile, _ = model(fusedcells)
        profile = profile.detach().numpy()[0,...]
        # Normalize profiles (per row)
        profile = (profile - np.min(profile)) / (np.max(profile) - np.min(profile))
        noutputs.append(profile)

    # Calculate PCAs
    pca = PCA(n_components=npcas, random_state=42)
    pcs = pca.fit_transform(np.stack(noutputs))

    fig, ax = plt.subplots(1,1, figsize = (10,10))
    for i in range(npcas):
        ax.plot(np.array(range(NPERM+1))/NPERM, pcs[:,i], label=f'PC{i+1}')
    ax.legend()

    ax.set_xlabel('admixing fraction')
    ax.set_ylabel('PC value')
    ax.set_title(f'saliency threshold: {frac}')
    plt.show()

#     fig, ax = plt.subplots(1,2, figsize = (15,10))
#     for i in range(npcas):
#         ax[0].plot(np.array(range(NPERM+1))/NPERM, pcs[:,i], label=f'PC{i+1}')
#     ax[0].legend()

#     ax[0].set_xlabel('admixing fraction')
#     ax[0].set_ylabel('PC value')
#     ax[0].set_title(f'saliency threshold: {frac}')
    
#     # Calculate signal to noise ratios 
#     snrs = SNR(np.stack(noutputs), 1)
#     ax[1].plot(np.array(range(NPERM+1))/NPERM, snrs)

#     ax[1].set_xlabel('admixing fraction')
#     ax[1].set_ylabel('SNR (-)')
#     ax[1].set_title(f'SNR with saliency threshold: {frac}')
#     plt.show()
# Out:
# 100%|███████████████████████████████████████| 3171/3171 [03:37<00:00, 14.58it/s]
# 100%|███████████████████████████████████████| 3147/3147 [03:44<00:00, 14.01it/s]
# 100%|███████████████████████████████████████| 2878/2878 [03:24<00:00, 14.05it/s]
# 100%|███████████████████████████████████████| 2924/2924 [03:26<00:00, 14.17it/s]
# torch.Size([604, 1324])
# 100%|███████████████████████████████████████| 3171/3171 [04:07<00:00, 12.80it/s]
# 100%|███████████████████████████████████████| 3147/3147 [04:12<00:00, 12.46it/s]
# 100%|███████████████████████████████████████| 2878/2878 [03:40<00:00, 13.06it/s]
# 100%|███████████████████████████████████████| 2924/2924 [03:26<00:00, 14.17it/s]
# torch.Size([1210, 1324])
# 100%|███████████████████████████████████████| 3171/3171 [03:48<00:00, 13.89it/s]
# 100%|███████████████████████████████████████| 3147/3147 [03:33<00:00, 14.71it/s]
# 100%|███████████████████████████████████████| 2878/2878 [03:03<00:00, 15.67it/s]
# 100%|███████████████████████████████████████| 2924/2924 [02:53<00:00, 16.88it/s]
# torch.Size([2422, 1324])
# 100%|███████████████████████████████████████| 3171/3171 [03:26<00:00, 15.39it/s]
# 100%|███████████████████████████████████████| 3147/3147 [03:15<00:00, 16.13it/s]
# 100%|███████████████████████████████████████| 2878/2878 [02:42<00:00, 17.68it/s]
# 100%|███████████████████████████████████████| 2924/2924 [02:46<00:00, 17.53it/s]
# torch.Size([4846, 1324])
# 100%|███████████████████████████████████████| 3171/3171 [03:31<00:00, 14.96it/s]
# 100%|███████████████████████████████████████| 3147/3147 [03:21<00:00, 15.65it/s]
# 100%|███████████████████████████████████████| 2878/2878 [02:43<00:00, 17.65it/s]
# 100%|███████████████████████████████████████| 2924/2924 [02:49<00:00, 17.25it/s]
# torch.Size([12120, 1324])
